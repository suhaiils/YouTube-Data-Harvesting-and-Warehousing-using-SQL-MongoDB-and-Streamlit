# %%
from googleapiclient.discovery import build
import pymongo

# %%
# API Key Connection

def Api_connect():
    Api_id="AIzaSyCFGygJ6TGn7xOsna_xONDnCCNQqhIFj-U"
    
    api_service_name="youtube"
    api_version="v3"
    
    youtube=build(api_service_name,api_version,developerKey=Api_id)
    
    return youtube

youtube=Api_connect()

# %%
# Get Channel Info

def get_channel_info(channel_id):
    request=youtube.channels().list(
                part="snippet,contentDetails,statistics",
                id=channel_id
    )

    response=request.execute()

    for i in response['items']:
        data=dict(Channel_Name=i['snippet']["title"],
                Channel_Id=i['id'],
                Subscribers=i['statistics']['subscriberCount'],
                Views=i['statistics']['viewCount'],
                Total_Videos=i['statistics']['videoCount'],
                Channel_Description=i['snippet']['description'],
                Playlist_Id=i['contentDetails']['relatedPlaylists']['uploads'])
        
    return data

# %%
channel_details=get_channel_info("UCA0UcljkR22RK2GSLi2w6ww")

# %%
channel_details
# Out:
# {'Channel_Name': 'SpilTrez',
#  'Channel_Id': 'UCA0UcljkR22RK2GSLi2w6ww',
#  'Subscribers': '68200',
#  'Views': '8442020',
#  'Total_Videos': '162',
#  'Channel_Description': "'Spil' is a Danish verb that applies to components of a game and 'Trez' refers to being loyal. \n\nHi, I’m SpilTrez, and I consider myself to be a loyal player in my game of motovlogging. Join Nora and me on our journey together through various ghats, hills, cities, potholes and whatnot.\n",
#  'Playlist_Id': 'UUA0UcljkR22RK2GSLi2w6ww'}

# %%
# Get Video Ids

def get_videos_ids(channel_id):
    video_ids=[]

    response=youtube.channels().list(
        id=channel_id,
        part="contentDetails").execute()

    Playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token=None


    while True:
        response1= youtube.playlistItems().list(
                                    part='snippet',
                                    playlistId=Playlist_Id,
                                    maxResults=50,
                                    pageToken=next_page_token).execute()

        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get('nextPageToken')
        
        if next_page_token is None:
            break
    return video_ids

# %%
Video_infos=get_videos_ids("UCA0UcljkR22RK2GSLi2w6ww")

# %%
len(Video_infos)
# Out:
# 163

# %%
Video_infos
# Out:
# ['UAEi3BSq11o',
#  '4TJ_2LkwGWU',
#  'ffuYlhtckEU',
#  'hKMtIdauKO0',
#  'TCJ-n-yEN8k',
#  'SgaoAATqI40',
#  'c0WFgFlCzq0',
#  'HYNm1unNrNA',
#  'VL32n3rTiqk',
#  'apQIy5RBoHE',
#  '8Ow4Tw-GreI',
#  'w5ymltuDsKI',
#  '29-aItNv2qY',
#  '9SzmXWXxA-E',
#  'ReiSOlXpNAI',
#  'yG7wI2pOYjQ',
#  'ppSyOC3yyj0',
#  'vIV8EeKmRXk',
#  'UgLr8GZSaQE',
#  '79XoRfDU2s4',
#  'hgWrMpUfVD4',
#  'ThLmiuUbcW8',
#  'icIeSoxWF0s',
#  'zpdt0NOQKB0',
#  'purCBEmtzgo',
#  'NdRX6hKsDAI',
#  'Fys84HasaMc',
#  'MwZXkKASNwg',
#  'tNagkVlZzmo',
#  'bxZEH6IyEz8',
#  'bnOQ7SagLk8',
#  'X5kmtV4gMM0',
#  'u2ifJSOPLVk',
#  'hgfGK_1QAaY',
#  'MsYW5qZFUOI',
#  '7UeLoXNL8II',
#  'FutWDZS8_6E',
#  'x1etD47EcxY',
#  'ukACpzi1ItA',
#  'XR3yDS4oVH4',
#  'WQzKvN9UvSs',
#  'L3UTGjAoLks',
#  'xdfOjVKPu_g',
#  'v9gG_iIvJkk',
#  '11Hm1foQaRQ',
#  'Bx3wmz6kQTk',
#  '_wVjtaBQUsU',
#  'gC7q72Pr8kA',
#  'ygBXB5cftCU',
#  'XY4WZlBSe_Y',
#  'kLE3AOYC42w',
#  'WNHnIeO0hhw',
#  'jnv-xaVKHHw',
#  'otheHXp_168',
#  'CsgFnZPYx5Q',
# ...

# %%
# Get Video Information

def get_video_info(video_ids):

    video_data = []

    for video_id in video_ids:
        request = youtube.videos().list(
                    part="snippet,contentDetails,statistics",
                    id= video_id)
        response = request.execute()

        for item in response["items"]:
            data = dict(Channel_Name = item['snippet']['channelTitle'],
                        Channel_Id = item['snippet']['channelId'],
                        Video_Id = item['id'],
                        Title = item['snippet']['title'],
                        Tags = item['snippet'].get('tags'),
                        Thumbnail = item['snippet']['thumbnails']['default']['url'],
                        Description = item['snippet']['description'],
                        Published_Date = item['snippet']['publishedAt'],
                        Duration = item['contentDetails']['duration'],
                        Views = item['statistics']['viewCount'],
                        Likes = item['statistics'].get('likeCount'),
                        Comments = item['statistics'].get('commentCount'),
                        Favorite_Count = item['statistics']['favoriteCount'],
                        Definition = item['contentDetails']['definition'],
                        Caption_Status = item['contentDetails']['caption']
                        )
            video_data.append(data)
    return video_data

# %%
video_details=get_video_info(Video_infos)

# %%
video_details
# Out:
# [{'Channel_Name': 'SpilTrez',
#   'Channel_Id': 'UCA0UcljkR22RK2GSLi2w6ww',
#   'Video_Id': 'UAEi3BSq11o',
#   'Title': 'BANGALORE TO SAKLESHPUR on Himalayan 450 | Long Ride Review',
#   'Tags': ['royal enfield',
#    'royal enfield Himalayan 450',
#    'Himalayan 450',
#    'Himalayan 450 royal enfield',
#    'Himalayan 450 top speed',
#    'royal enfield Himalayan 450 review',
#    'royal enfield himalayan 450 price in india',
#    'himalayan 450 exhaust sound',
#    'himalayan 450 review',
#    'royal enfield himalayan 450 exhaust sound',
#    'royal enfield himalayan 450 top speed',
#    'himalayan 450 exhaust change',
#    'spiltrez',
#    'bangalore to sakleshpur',
#    'himalayan 450 offroading',
#    'offroad',
#    'off road',
#    'spiltrez rides himalayan 450'],
#   'Thumbnail': 'https://i.ytimg.com/vi/UAEi3BSq11o/default.jpg',
# ...

# %%
#Get Comment Information
def get_comment_info(video_ids):
    Comment_data=[]
    try:
        for video_id in video_ids:
            request=youtube.commentThreads().list(
                        part='snippet',
                        videoId=video_ids,
                        maxResults=50
            )
            response=request.execute()

            for item in response['items']:
                data=dict( 
                        Comment_Id = item["snippet"]["topLevelComment"]["id"],
                        Video_Id = item["snippet"]["videoId"],
                        Comment_Text = item["snippet"]["topLevelComment"]["snippet"]["textOriginal"],
                        Comment_Author = item["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"],
                        Comment_Published = item["snippet"]["topLevelComment"]["snippet"]["publishedAt"])
                Comment_data.append(data)
        
    except:
        pass
    return Comment_data

# %%
comment_details=get_comment_info(Video_infos)

# %%
len(comment_details)
# Out:
# 0

# %%
#get playlist ids
def get_playlist_details(channel_id):
    All_data = []
    next_page_token = None
    next_page = True
    while next_page:

        request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token
            )
        response = request.execute()

        for item in response['items']: 
            data={'PlaylistId':item['id'],
                    'Title':item['snippet']['title'],
                    'ChannelId':item['snippet']['channelId'],
                    'ChannelName':item['snippet']['channelTitle'],
                    'PublishedAt':item['snippet']['publishedAt'],
                    'VideoCount':item['contentDetails']['itemCount']}
            All_data.append(data)
        next_page_token = response.get('nextPageToken')
        if next_page_token is None:
            next_page=False
    return All_data

# %%
playlist_details=get_playlist_details("UCA0UcljkR22RK2GSLi2w6ww")

# %%
len(playlist_details)
# Out:
# 7

# %%
client=pymongo.MongoClient("mongodb+srv://suhaiil:suhaiil@cluster0.b5ya42r.mongodb.net/?retryWrites=true&w=majority")
db = client["Youtube_data"]
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 client=pymongo.MongoClient("mongodb+srv://suhaiil:suhaiil@cluster0.b5ya42r.mongodb.net/?retryWrites=true&w=majority")
#       2 db = client["Youtube_data"]
#
# File c:\Users\Suhaiil S\Desktop\Youtube Capstone\.venv\Lib\site-packages\pymongo\mongo_client.py:771, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     767 if timeout is not None:
#     768     timeout = common.validate_timeout_or_none_or_zero(
#     769         keyword_opts.cased_key("connecttimeoutms"), timeout
#     770     )
# --> 771 res = uri_parser.parse_uri(
#     772     entity,
#     773     port,
#     774     validate=True,
#     775     warn=True,
#     776     normalize=False,
#     777     connect_timeout=timeout,
#     778     srv_service_name=srv_service_name,
# ...
